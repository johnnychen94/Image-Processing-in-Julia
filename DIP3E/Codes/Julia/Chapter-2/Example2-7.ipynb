# %% [markdown]
# **Example 2.7:** Using image multiplication and division for shading correction.
#
# This includes figure 2.29 and 2.30
#
# > This code is written with Julia v1.0.0

# %%
cd("/home/jc/Documents/Digital-Image-Processing-Gonzalez/DIP3E/Codes/Julia/Chapter-2/")
using Printf # format string in C style
using Images # core package for image

# %% [markdown]
# ## Figure 2.29 阴影矫正

# %%
img_shaded = load("Data/Fig0229(a)(tungsten_filament_shaded).tif") .|> float32 # use Float32 to avoid unwanted overflow in N0f8
img_mask = load("Data/Fig0229(b)(tungsten_sensor_shading).tif") .|> float32
@show summary(img_shaded) summary(img_mask)
    
img_corrected = img_shaded ./ img_mask .|> Gray
    
[img_shaded img_mask img_corrected]
# Out:
# summary(img_shaded) = "892×754 Array{Gray{Float32},2} with eltype Gray{Float32}"
# summary(img_mask) = "892×754 Array{Gray{Float32},2} with eltype Gray{Float32}"
# 892×2262 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.00784314)  …  Gray{Float32}(0.103448)
#  Gray{Float32}(0.00784314)     Gray{Float32}(0.103448)
#  Gray{Float32}(0.00392157)     Gray{Float32}(0.103448)
#  Gray{Float32}(0.00392157)     Gray{Float32}(0.103448)
#  Gray{Float32}(0.00392157)     Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)            Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)            Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)            Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)            Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)            Gray{Float32}(0.103448)
#  Gray{Float32}(0.0)            Gray{Float32}(0.103448)
#  ⋮                          ⋱
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.717949)
#  Gray{Float32}(0.0)            Gray{Float32}(0.717949)
#  Gray{Float32}(0.0)            Gray{Float32}(0.714286)
#  Gray{Float32}(0.0)            Gray{Float32}(0.792208)
#  Gray{Float32}(0.0)            Gray{Float32}(0.792208)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.792208)
#  Gray{Float32}(0.0)            Gray{Float32}(0.779221)
#  Gray{Float32}(0.0)            Gray{Float32}(0.776316)
#  Gray{Float32}(0.0)            Gray{Float32}(0.776316)
#  Gray{Float32}(0.0)            Gray{Float32}(0.657895)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.657895)
#  Gray{Float32}(0.0)            Gray{Float32}(0.657895)

# %% [markdown]
# ## Figure 2.30 ROI提取

# %%
img_ori = load("Data/Fig0230(a)(dental_xray).tif") .|> float32
img_mask = load("Data/Fig0230(b)(dental_xray_mask).tif") .|> float32
@show summary(img_ori) summary(img_mask)

img_roi = img_ori .* img_mask .|> Gray

[img_ori img_mask img_roi]
# Out:
# summary(img_ori) = "674×882 Array{Gray{Float32},2} with eltype Gray{Float32}"
# summary(img_mask) = "674×882 Array{Gray{Float32},2} with eltype Gray{Float32}"
# 674×2646 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.847059)  Gray{Float32}(0.839216)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.839216)  Gray{Float32}(0.839216)     Gray{Float32}(0.0)
#  Gray{Float32}(0.831373)  Gray{Float32}(0.827451)     Gray{Float32}(0.0)
#  Gray{Float32}(0.831373)  Gray{Float32}(0.823529)     Gray{Float32}(0.0)
#  Gray{Float32}(0.827451)  Gray{Float32}(0.823529)     Gray{Float32}(0.0)
#  Gray{Float32}(0.831373)  Gray{Float32}(0.811765)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.827451)  Gray{Float32}(0.827451)     Gray{Float32}(0.0)
#  Gray{Float32}(0.827451)  Gray{Float32}(0.827451)     Gray{Float32}(0.0)
#  Gray{Float32}(0.839216)  Gray{Float32}(0.827451)     Gray{Float32}(0.0)
#  Gray{Float32}(0.823529)  Gray{Float32}(0.823529)     Gray{Float32}(0.0)
#  Gray{Float32}(0.823529)  Gray{Float32}(0.823529)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.819608)  Gray{Float32}(0.815686)     Gray{Float32}(0.0)
#  Gray{Float32}(0.803922)  Gray{Float32}(0.815686)     Gray{Float32}(0.0)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float32}(0.6)       Gray{Float32}(0.576471)     Gray{Float32}(0.0)
#  Gray{Float32}(0.596078)  Gray{Float32}(0.580392)     Gray{Float32}(0.0)
#  Gray{Float32}(0.580392)  Gray{Float32}(0.564706)     Gray{Float32}(0.0)
#  Gray{Float32}(0.576471)  Gray{Float32}(0.54902)   …  Gray{Float32}(0.0)
#  Gray{Float32}(0.545098)  Gray{Float32}(0.556863)     Gray{Float32}(0.0)
#  Gray{Float32}(0.556863)  Gray{Float32}(0.509804)     Gray{Float32}(0.0)
#  Gray{Float32}(0.556863)  Gray{Float32}(0.537255)     Gray{Float32}(0.0)
#  Gray{Float32}(0.564706)  Gray{Float32}(0.54902)      Gray{Float32}(0.0)
#  Gray{Float32}(0.568627)  Gray{Float32}(0.552941)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.580392)  Gray{Float32}(0.568627)     Gray{Float32}(0.0)
#  Gray{Float32}(0.568627)  Gray{Float32}(0.568627)     Gray{Float32}(0.0)
#  Gray{Float32}(0.576471)  Gray{Float32}(0.568627)     Gray{Float32}(0.56103)
