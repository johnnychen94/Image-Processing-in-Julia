# %% [markdown]
# **Example 2.6:** Image substraction for enhancing differences
#
# This includes Figure 2.27 and 2.28
#
# > This code is written with Julia v1.0.0
#
# Note: I'm not sure how to implement Figure 2.27(b), so just skip it here.

# %%
cd("/home/jc/Documents/Digital-Image-Processing-Gonzalez/DIP3E/Codes/Julia/Chapter-2/")
using Printf # format string in C style
using Images # core package for image

# %%
mask_img = load("Data/Fig0228(a).tif") .|> float32 # use Float32 to avoid unwanted overflow in N0f8
live_img = load("Data/Fig0228(b).tif") .|> float32
@show summary(mask_img) summary(live_img)
hcat(mask_img,live_img)
# Out:
# summary(mask_img) = "420×420 Array{Gray{Float32},2} with eltype Gray{Float32}"
# summary(live_img) = "420×420 Array{Gray{Float32},2} with eltype Gray{Float32}"
# 420×840 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)

# %%
diff_img = imadjustintensity(live_img - mask_img)
enhanced_diff_img = colorview(Gray, exp10.(channelview(diff_img))) |> imadjustintensity

[mask_img live_img; diff_img enhanced_diff_img]
# Out:
# 840×840 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)  …  Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  Gray{Float32}(0.854902)  Gray{Float32}(0.854902)     Gray{Float32}(0.854902)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)  …  Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)  …  Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
#  Gray{Float32}(0.666667)  Gray{Float32}(0.666667)     Gray{Float32}(0.404621)
